# %% [markdown]
#  #### Create table in mysql
# ```shell
# MariaDB [(none)]> show create table retail_export.itv002768_covid19_india\G
# *************************** 1. row ***************************
#        Table: itv002768_covid19_india
# Create Table: CREATE TABLE `itv002768_covid19_india` (
#   `sno` int(11) NOT NULL,
#   `date_time` varchar(20) DEFAULT NULL,
#   `state` varchar(100) DEFAULT NULL,
#   `cured` int(11) DEFAULT NULL,
#   `death` int(11) DEFAULT NULL,
#   `confirmed` int(11) DEFAULT NULL,
#   PRIMARY KEY (`sno`)
# ) ENGINE=InnoDB DEFAULT CHARSET=latin1
# 1 row in set (0.00 sec)
#
# MariaDB [(none)]> show create table retail_export.itv002768_state_wise_testing\G
# *************************** 1. row ***************************
#        Table: itv002768_state_wise_testing
# Create Table: CREATE TABLE `itv002768_state_wise_testing` (
#   `seq` int(11) NOT NULL,
#   `date_time` varchar(20) DEFAULT NULL,
#   `state` varchar(100) DEFAULT NULL,
#   `total_samples` int(11) DEFAULT NULL,
#   `negative` int(11) DEFAULT NULL,
#   `positive` int(11) DEFAULT NULL,
#   PRIMARY KEY (`seq`)
# ) ENGINE=InnoDB DEFAULT CHARSET=latin1
# 1 row in set (0.03 sec)
# ```
# #### Create staging tables
#
# ```shell
# MariaDB [(none)]> create table  retail_export.itv002768_state_wise_testing_staging like  retail_export.itv002768_state_wise_testing;
# Query OK, 0 rows affected (0.09 sec)
#
# MariaDB [(none)]> create table  retail_export.itv002768_covid19_india_staging like  retail_export.itv002768_covid19_india;
# Query OK, 0 rows affected (0.08 sec)
# ```
#
# #### Move the data in HDFS
#
# ```shell
#
# [itv002768@g02 ~]$ hadoop fs -ls
# Found 13 items
# drwx------   - itv002768 supergroup          0 2022-06-10 06:02 .Trash
# drwxr-xr-x   - itv002768 supergroup          0 2022-06-14 13:14 _sqoop
# drwxr-xr-x   - itv002768 supergroup          0 2022-06-10 06:14 allretail_db
# drwxr-xr-x   - itv002768 supergroup          0 2022-06-12 03:04 allretail_db_compress
# drwxr-xr-x   - itv002768 supergroup          0 2022-06-12 03:08 allretail_db_compress_bzip
# drwxr-xr-x   - itv002768 supergroup          0 2022-06-14 13:14 data_info
# drwxr-xr-x   - itv002768 supergroup          0 2022-05-24 14:16 mapreduce_test
# drwxr-xr-x   - itv002768 supergroup          0 2022-06-10 06:02 queryresult
# drwxr-xr-x   - itv002768 supergroup          0 2022-06-12 02:51 queryresult1
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-10 02:48 test_dir
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-10 02:50 tushar_test
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-09 23:30 warehouse
#
# [itv002768@g02 ~]$ hadoop fs -mkdir week5_assignment
#
# [itv002768@g02 ~]$ hadoop fs -put week5_assignment/* week5_assignment/
#
# [itv002768@g02 ~]$ hadoop fs -ls week5_assignment
# Found 2 items
# -rw-r--r--   3 itv002768 supergroup      85487 2022-07-24 00:34 week5_assignment/Covid19_india-201004-194827.csv
# -rw-r--r--   3 itv002768 supergroup      77259 2022-07-24 00:34 week5_assignment/StatewiseTestingDetails-201004-194827.csv
# ```
#
# #### Export data in mysql
#
# ```shell
# [itv002768@g02 ~]$ sqoop export --connect jdbc:mysql://ms.itversity.com:3306/retail_export --username retail_user --table itv002768_covid19_india --fields-terminated-by ',' --export-dir week5_assignment/Covid19_india-201004-194827.csv --staging-table itv002768_covid19_india_staging --password-file file:///home/itv0
# 02768/.password_file
# Warning: /opt/sqoop/../hcatalog does not exist! HCatalog jobs will fail.
# Please set $HCAT_HOME to the root of your HCatalog installation.
# Warning: /opt/sqoop/../accumulo does not exist! Accumulo imports will fail.
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hadoop-3.3.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/apache-hive-3.1.2-bin/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2022-07-24 01:21:15,416 INFO sqoop.Sqoop: Running Sqoop version: 1.4.7
# 2022-07-24 01:21:17,040 INFO manager.MySQLManager: Preparing to use a MySQL streaming resultset.
# 2022-07-24 01:21:17,042 INFO tool.CodeGenTool: Beginning code generation
# 2022-07-24 01:21:17,775 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `itv002768_covid19_india` AS t LIMIT 1
# 2022-07-24 01:21:17,810 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `itv002768_covid19_india` AS t LIMIT 1
# 2022-07-24 01:21:17,813 INFO orm.CompilationManager: HADOOP_MAPRED_HOME is /opt/hadoop
# Note: /tmp/sqoop-itv002768/compile/387e1e4483c2e46f52c0b772dc3ff903/itv002768_covid19_india.java uses or overrides a deprecated API.
# Note: Recompile with -Xlint:deprecation for details.
# 2022-07-24 01:21:20,994 INFO orm.CompilationManager: Writing jar file: /tmp/sqoop-itv002768/compile/387e1e4483c2e46f52c0b772dc3ff903/itv002768_covid19_india.jar
# 2022-07-24 01:21:21,000 INFO mapreduce.ExportJobBase: Data will be staged in the table: itv002768_covid19_india_staging
# 2022-07-24 01:21:21,001 INFO mapreduce.ExportJobBase: Beginning export of itv002768_covid19_india
# 2022-07-24 01:21:21,001 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2022-07-24 01:21:21,024 INFO Configuration.deprecation: mapred.jar is deprecated. Instead, use mapreduce.job.jar
# 2022-07-24 01:21:21,876 INFO Configuration.deprecation: mapred.reduce.tasks.speculative.execution is deprecated. Instead, use mapreduce.reduce.speculative
# 2022-07-24 01:21:21,879 INFO Configuration.deprecation: mapred.map.tasks.speculative.execution is deprecated. Instead, use mapreduce.map.speculative
# 2022-07-24 01:21:21,879 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2022-07-24 01:21:22,270 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at m02.itversity.com/172.16.1.104:8032
# 2022-07-24 01:21:22,604 INFO client.AHSProxy: Connecting to Application History server at m01.itversity.com/172.16.1.103:10200
# 2022-07-24 01:21:22,889 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/itv002768/.staging/job_1658206934431_2404
# 2022-07-24 01:21:27,810 INFO input.FileInputFormat: Total input files to process : 1
# 2022-07-24 01:21:27,812 INFO input.FileInputFormat: Total input files to process : 1
# 2022-07-24 01:21:28,059 INFO mapreduce.JobSubmitter: number of splits:4
# 2022-07-24 01:21:28,344 INFO Configuration.deprecation: mapred.map.tasks.speculative.execution is deprecated. Instead, use mapreduce.map.speculative
# 2022-07-24 01:21:28,660 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1658206934431_2404
# 2022-07-24 01:21:28,660 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2022-07-24 01:21:28,977 INFO conf.Configuration: resource-types.xml not found
# 2022-07-24 01:21:28,977 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 2022-07-24 01:21:29,026 INFO impl.YarnClientImpl: Submitted application application_1658206934431_2404
# 2022-07-24 01:21:29,046 INFO mapreduce.Job: The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2404/
# 2022-07-24 01:21:29,046 INFO mapreduce.Job: Running job: job_1658206934431_2404
# 2022-07-24 01:21:33,124 INFO mapreduce.Job: Job job_1658206934431_2404 running in uber mode : false
# 2022-07-24 01:21:33,139 INFO mapreduce.Job:  map 0% reduce 0%
# 2022-07-24 01:21:37,214 INFO mapreduce.Job:  map 100% reduce 0%
# 2022-07-24 01:21:38,240 INFO mapreduce.Job: Job job_1658206934431_2404 completed successfully
# 2022-07-24 01:21:38,305 INFO mapreduce.Job: Counters: 33
#         File System Counters
#                 FILE: Number of bytes read=0
#                 FILE: Number of bytes written=1098728
#                 FILE: Number of read operations=0
#                 FILE: Number of large read operations=0
#                 FILE: Number of write operations=0
#                 HDFS: Number of bytes read=102692
#                 HDFS: Number of bytes written=0
#                 HDFS: Number of read operations=19
#                 HDFS: Number of large read operations=0
#                 HDFS: Number of write operations=0
#                 HDFS: Number of bytes read erasure-coded=0
#         Job Counters
#                 Launched map tasks=4
#                 Data-local map tasks=4
#                 Total time spent by all maps in occupied slots (ms)=8837
#                 Total time spent by all reduces in occupied slots (ms)=0
#                 Total time spent by all map tasks (ms)=8837
#                 Total vcore-milliseconds taken by all map tasks=8837
#                 Total megabyte-milliseconds taken by all map tasks=9049088
#         Map-Reduce Framework
#                 Map input records=2390
#                 Map output records=2390
#                 Input split bytes=806
#                 Spilled Records=0
#                 Failed Shuffles=0
#                 Merged Map outputs=0
#                 GC time elapsed (ms)=148
#                 CPU time spent (ms)=2710
#                 Physical memory (bytes) snapshot=1218703360
#                 Virtual memory (bytes) snapshot=10494951424
#                 Total committed heap usage (bytes)=2528116736
#                 Peak Map Physical memory (bytes)=307703808
#                 Peak Map Virtual memory (bytes)=2627645440
#         File Input Format Counters
#                 Bytes Read=0
#         File Output Format Counters
#                 Bytes Written=0
# 2022-07-24 01:21:38,309 INFO mapreduce.ExportJobBase: Transferred 100.2852 KB in 16.4245 seconds (6.1058 KB/sec)
# 2022-07-24 01:21:38,312 INFO mapreduce.ExportJobBase: Exported 2390 records.
# 2022-07-24 01:21:38,312 INFO mapreduce.ExportJobBase: Starting to migrate data from staging table to destination.
# 2022-07-24 01:21:38,317 INFO manager.SqlManager: Migrated 2390 records from `itv002768_covid19_india_staging` to `itv002768_covid19_india`
#
# [itv002768@g02 ~]$ sqoop export --connect jdbc:mysql://ms.itversity.com:3306/retail_export --username retail_user --table itv002768_state_wise_testing --fields-terminated-by ',' --export-dir week5_assignment/StatewiseTestingDetails-201004-194827.csv --staging-table itv002768_state_wise_testing_staging --password-file file:///home/itv002768/.password_file
# Warning: /opt/sqoop/../hcatalog does not exist! HCatalog jobs will fail.
# Please set $HCAT_HOME to the root of your HCatalog installation.
# Warning: /opt/sqoop/../accumulo does not exist! Accumulo imports will fail.
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hadoop-3.3.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/apache-hive-3.1.2-bin/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2022-07-24 01:22:50,363 INFO sqoop.Sqoop: Running Sqoop version: 1.4.7
# 2022-07-24 01:22:50,586 INFO manager.MySQLManager: Preparing to use a MySQL streaming resultset.
# 2022-07-24 01:22:50,588 INFO tool.CodeGenTool: Beginning code generation
# 2022-07-24 01:22:50,862 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `itv002768_state_wise_testing` AS t LIMIT 1
# 2022-07-24 01:22:50,877 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `itv002768_state_wise_testing` AS t LIMIT 1
# 2022-07-24 01:22:50,880 INFO orm.CompilationManager: HADOOP_MAPRED_HOME is /opt/hadoop
# Note: /tmp/sqoop-itv002768/compile/334a601abdd3f0cb7eefb36b4f91759a/itv002768_state_wise_testing.java uses or overrides a deprecated API.
# Note: Recompile with -Xlint:deprecation for details.
# 2022-07-24 01:22:51,837 INFO orm.CompilationManager: Writing jar file: /tmp/sqoop-itv002768/compile/334a601abdd3f0cb7eefb36b4f91759a/itv002768_state_wise_testing.jar
# 2022-07-24 01:22:51,843 INFO mapreduce.ExportJobBase: Data will be staged in the table: itv002768_state_wise_testing_staging
# 2022-07-24 01:22:51,843 INFO mapreduce.ExportJobBase: Beginning export of itv002768_state_wise_testing
# 2022-07-24 01:22:51,844 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2022-07-24 01:22:51,847 INFO Configuration.deprecation: mapred.jar is deprecated. Instead, use mapreduce.job.jar
# 2022-07-24 01:22:52,186 INFO Configuration.deprecation: mapred.reduce.tasks.speculative.execution is deprecated. Instead, use mapreduce.reduce.speculative
# 2022-07-24 01:22:52,188 INFO Configuration.deprecation: mapred.map.tasks.speculative.execution is deprecated. Instead, use mapreduce.map.speculative
# 2022-07-24 01:22:52,188 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2022-07-24 01:22:52,370 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at m02.itversity.com/172.16.1.104:8032
# 2022-07-24 01:22:52,440 INFO client.AHSProxy: Connecting to Application History server at m01.itversity.com/172.16.1.103:10200
# 2022-07-24 01:22:52,519 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/itv002768/.staging/job_1658206934431_2405
# 2022-07-24 01:22:56,747 INFO input.FileInputFormat: Total input files to process : 1
# 2022-07-24 01:22:56,750 INFO input.FileInputFormat: Total input files to process : 1
# 2022-07-24 01:22:56,945 INFO mapreduce.JobSubmitter: number of splits:4
# 2022-07-24 01:22:57,024 INFO Configuration.deprecation: mapred.map.tasks.speculative.execution is deprecated. Instead, use mapreduce.map.speculative
# 2022-07-24 01:22:57,156 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1658206934431_2405
# 2022-07-24 01:22:57,156 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2022-07-24 01:22:57,291 INFO conf.Configuration: resource-types.xml not found
# 2022-07-24 01:22:57,292 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 2022-07-24 01:22:57,323 INFO impl.YarnClientImpl: Submitted application application_1658206934431_2405
# 2022-07-24 01:22:57,346 INFO mapreduce.Job: The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2405/
# 2022-07-24 01:22:57,346 INFO mapreduce.Job: Running job: job_1658206934431_2405
# 2022-07-24 01:23:01,447 INFO mapreduce.Job: Job job_1658206934431_2405 running in uber mode : false
# 2022-07-24 01:23:01,450 INFO mapreduce.Job:  map 0% reduce 0%
# 2022-07-24 01:23:05,490 INFO mapreduce.Job:  map 100% reduce 0%
# 2022-07-24 01:23:06,510 INFO mapreduce.Job: Job job_1658206934431_2405 completed successfully
# 2022-07-24 01:23:06,556 INFO mapreduce.Job: Counters: 33
#         File System Counters
#                 FILE: Number of bytes read=0
#                 FILE: Number of bytes written=1098868
#                 FILE: Number of read operations=0
#                 FILE: Number of large read operations=0
#                 FILE: Number of write operations=0
#                 HDFS: Number of bytes read=94514
#                 HDFS: Number of bytes written=0
#                 HDFS: Number of read operations=19
#                 HDFS: Number of large read operations=0
#                 HDFS: Number of write operations=0
#                 HDFS: Number of bytes read erasure-coded=0
#         Job Counters
#                 Launched map tasks=4
#                 Data-local map tasks=4
#                 Total time spent by all maps in occupied slots (ms)=8555
#                 Total time spent by all reduces in occupied slots (ms)=0
#                 Total time spent by all map tasks (ms)=8555
#                 Total vcore-milliseconds taken by all map tasks=8555
#                 Total megabyte-milliseconds taken by all map tasks=8760320
#         Map-Reduce Framework
#                 Map input records=1922
#                 Map output records=1922
#                 Input split bytes=856
#                 Spilled Records=0
#                 Failed Shuffles=0
#                 Merged Map outputs=0
#                 GC time elapsed (ms)=119
#                 CPU time spent (ms)=2420
#                 Physical memory (bytes) snapshot=1198514176
#                 Virtual memory (bytes) snapshot=10489458688
#                 Total committed heap usage (bytes)=2512912384
#                 Peak Map Physical memory (bytes)=300814336
#                 Peak Map Virtual memory (bytes)=2623569920
#         File Input Format Counters
#                 Bytes Read=0
#         File Output Format Counters
#                 Bytes Written=0
# 2022-07-24 01:23:06,560 INFO mapreduce.ExportJobBase: Transferred 92.2988 KB in 14.3661 seconds (6.4248 KB/sec)
# 2022-07-24 01:23:06,562 INFO mapreduce.ExportJobBase: Exported 1922 records.
# 2022-07-24 01:23:06,562 INFO mapreduce.ExportJobBase: Starting to migrate data from staging table to destination.
# 2022-07-24 01:23:06,566 INFO manager.SqlManager: Migrated 1922 records from `itv002768_state_wise_testing_staging` to `itv002768_state_wise_testing`
#
# # alias mysql_login='mysql -u retail_user -pitversity -h ms.itversity.com -P 3306'
#
# [itv002768@g02 ~]$ mysql_login
# Welcome to the MariaDB monitor.  Commands end with ; or \g.
# Your MariaDB connection id is 44916
# Server version: 5.5.68-MariaDB MariaDB Server
#
# Copyright (c) 2000, 2018, Oracle, MariaDB Corporation Ab and others.
#
# Type 'help;' or '\h' for help. Type '\c' to clear the current input statement.
#
# MariaDB [(none)]> select * from retail_export.itv002768_covid19_india limit 10;
# +-----+-----------+-----------------------------+-------+-------+-----------+
# | sno | date_time | state                       | cured | death | confirmed |
# +-----+-----------+-----------------------------+-------+-------+-----------+
# | 530 | 1/4/2020  | Andhra Pradesh              |     1 |     0 |        83 |
# | 531 | 1/4/2020  | Andaman and Nicobar Islands |     0 |     0 |        10 |
# | 532 | 1/4/2020  | Assam                       |     0 |     0 |         1 |
# | 533 | 1/4/2020  | Bihar                       |     0 |     1 |        23 |
# | 534 | 1/4/2020  | Chandigarh                  |     0 |     0 |        16 |
# | 535 | 1/4/2020  | Chhattisgarh                |     2 |     0 |         9 |
# | 536 | 1/4/2020  | Delhi                       |     6 |     2 |       152 |
# | 537 | 1/4/2020  | Goa                         |     0 |     0 |         5 |
# | 538 | 1/4/2020  | Gujarat                     |     5 |     6 |        82 |
# | 539 | 1/4/2020  | Haryana                     |    21 |     0 |        43 |
# +-----+-----------+-----------------------------+-------+-------+-----------+
# 10 rows in set (0.00 sec)
#
# MariaDB [(none)]> select * from retail_export.itv002768_state_wise_testing limit 10;
# +-----+-----------+-----------------------------+---------------+----------+----------+
# | seq | date_time | state                       | total_samples | negative | positive |
# +-----+-----------+-----------------------------+---------------+----------+----------+
# |   1 | 4/17/2020 | Andaman and Nicobar Islands |          1403 |     1210 |       12 |
# |   2 | 4/24/2020 | Andaman and Nicobar Islands |          2679 |     NULL |       27 |
# |   3 | 4/27/2020 | Andaman and Nicobar Islands |          2848 |     NULL |       33 |
# |   4 | 5/1/2020  | Andaman and Nicobar Islands |          3754 |     NULL |       33 |
# |   5 | 5/16/2020 | Andaman and Nicobar Islands |          6677 |     NULL |       33 |
# |   6 | 5/19/2020 | Andaman and Nicobar Islands |          6965 |     NULL |       33 |
# |   7 | 5/20/2020 | Andaman and Nicobar Islands |          7082 |     NULL |       33 |
# |   8 | 5/21/2020 | Andaman and Nicobar Islands |          7167 |     NULL |       33 |
# |   9 | 5/22/2020 | Andaman and Nicobar Islands |          7263 |     NULL |       33 |
# |  10 | 5/23/2020 | Andaman and Nicobar Islands |          7327 |     NULL |       33 |
# +-----+-----------+-----------------------------+---------------+----------+----------+
# 10 rows in set (0.00 sec)
# ```

# %% [markdown]
# ## Moving data to hadoop
#
# #### Create Sqoop import jobs
# ```shell
# [itv002768@g02 ~]$ sqoop job --create load_covid_info_india -- import --connect jdbc:mysql://ms.itversity.com:3306/retail_export --username retail_user --table itv002768_covid19_india --warehouse-dir week5_assignment_hadoop_data --incremental append --password-file file:///home/itv002768/.password_file --null-string "0" --check-column sno
# Warning: /opt/sqoop/../hcatalog does not exist! HCatalog jobs will fail.
# Please set $HCAT_HOME to the root of your HCatalog installation.
# Warning: /opt/sqoop/../accumulo does not exist! Accumulo imports will fail.
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hadoop-3.3.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/apache-hive-3.1.2-bin/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2022-07-24 01:48:54,107 INFO sqoop.Sqoop: Running Sqoop version: 1.4.7
# [itv002768@g02 ~]$ sqoop job --create load_covid_testing_data -- import --connect jdbc:mysql://ms.itversity.com:3306/retail_export --username retail_user --table itv002768_state_wise_testing --warehouse-dir week5_assignment_hadoop_data --incremental append --password-file file:///home/itv002768/.password_file --nul
# l-string "0" --check-column seq
# Warning: /opt/sqoop/../hcatalog does not exist! HCatalog jobs will fail.
# Please set $HCAT_HOME to the root of your HCatalog installation.
# Warning: /opt/sqoop/../accumulo does not exist! Accumulo imports will fail.
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hadoop-3.3.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/apache-hive-3.1.2-bin/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2022-07-24 01:49:16,806 INFO sqoop.Sqoop: Running Sqoop version: 1.4.7
# [itv002768@g02 ~]$ sqoop job --list
# Warning: /opt/sqoop/../hcatalog does not exist! HCatalog jobs will fail.
# Please set $HCAT_HOME to the root of your HCatalog installation.
# Warning: /opt/sqoop/../accumulo does not exist! Accumulo imports will fail.
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hadoop-3.3.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/apache-hive-3.1.2-bin/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2022-07-24 01:49:23,160 INFO sqoop.Sqoop: Running Sqoop version: 1.4.7
# Available jobs:
#   job_orders
#   load_covid_info_india
#   load_covid_testing_data
# ```
#
# #### Run the sqoop jobs
# ```shell
# [itv002768@g02 ~]$ sqoop job --exec load_covid_info_india
# Warning: /opt/sqoop/../hcatalog does not exist! HCatalog jobs will fail.
# Please set $HCAT_HOME to the root of your HCatalog installation.
# Warning: /opt/sqoop/../accumulo does not exist! Accumulo imports will fail.
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hadoop-3.3.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/apache-hive-3.1.2-bin/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2022-07-24 01:49:34,952 INFO sqoop.Sqoop: Running Sqoop version: 1.4.7
# 2022-07-24 01:49:35,366 INFO manager.MySQLManager: Preparing to use a MySQL streaming resultset.
# 2022-07-24 01:49:35,366 INFO tool.CodeGenTool: Beginning code generation
# 2022-07-24 01:49:35,596 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `itv002768_covid19_india` AS t LIMIT 1
# 2022-07-24 01:49:35,627 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `itv002768_covid19_india` AS t LIMIT 1
# 2022-07-24 01:49:35,630 INFO orm.CompilationManager: HADOOP_MAPRED_HOME is /opt/hadoop
# Note: /tmp/sqoop-itv002768/compile/cbccd89fbe36905a7810c821b4df4849/itv002768_covid19_india.java uses or overrides a deprecated API.
# Note: Recompile with -Xlint:deprecation for details.
# 2022-07-24 01:49:36,463 INFO orm.CompilationManager: Writing jar file: /tmp/sqoop-itv002768/compile/cbccd89fbe36905a7810c821b4df4849/itv002768_covid19_india.jar
# 2022-07-24 01:49:36,470 INFO tool.ImportTool: Maximal id query for free form incremental import: SELECT MAX(`sno`) FROM `itv002768_covid19_india`
# 2022-07-24 01:49:36,470 INFO tool.ImportTool: Incremental import based on column `sno`
# 2022-07-24 01:49:36,470 INFO tool.ImportTool: Upper bound value: 2919
# 2022-07-24 01:49:36,470 WARN manager.MySQLManager: It looks like you are importing from mysql.
# 2022-07-24 01:49:36,470 WARN manager.MySQLManager: This transfer can be faster! Use the --direct
# 2022-07-24 01:49:36,470 WARN manager.MySQLManager: option to exercise a MySQL-specific fast path.
# 2022-07-24 01:49:36,470 INFO manager.MySQLManager: Setting zero DATETIME behavior to convertToNull (mysql)
# 2022-07-24 01:49:36,472 INFO mapreduce.ImportJobBase: Beginning import of itv002768_covid19_india
# 2022-07-24 01:49:36,473 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2022-07-24 01:49:36,476 INFO Configuration.deprecation: mapred.jar is deprecated. Instead, use mapreduce.job.jar
# 2022-07-24 01:49:36,726 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2022-07-24 01:49:36,847 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at m02.itversity.com/172.16.1.104:8032
# 2022-07-24 01:49:36,984 INFO client.AHSProxy: Connecting to Application History server at m01.itversity.com/172.16.1.103:10200
# 2022-07-24 01:49:37,169 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/itv002768/.staging/job_1658206934431_2413
# 2022-07-24 01:49:45,473 INFO db.DBInputFormat: Using read commited transaction isolation
# 2022-07-24 01:49:45,474 INFO db.DataDrivenDBInputFormat: BoundingValsQuery: SELECT MIN(`sno`), MAX(`sno`) FROM `itv002768_covid19_india` WHERE ( `sno` <= 2919 )
# 2022-07-24 01:49:45,481 INFO db.IntegerSplitter: Split size: 597; Num splits: 4 from: 530 to: 2919
# 2022-07-24 01:49:45,715 INFO mapreduce.JobSubmitter: number of splits:4
# 2022-07-24 01:49:45,942 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1658206934431_2413
# 2022-07-24 01:49:45,942 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2022-07-24 01:49:46,116 INFO conf.Configuration: resource-types.xml not found
# 2022-07-24 01:49:46,116 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 2022-07-24 01:49:46,151 INFO impl.YarnClientImpl: Submitted application application_1658206934431_2413
# 2022-07-24 01:49:46,172 INFO mapreduce.Job: The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2413/
# 2022-07-24 01:49:46,173 INFO mapreduce.Job: Running job: job_1658206934431_2413
# 2022-07-24 01:49:50,225 INFO mapreduce.Job: Job job_1658206934431_2413 running in uber mode : false
# 2022-07-24 01:49:50,228 INFO mapreduce.Job:  map 0% reduce 0%
# 2022-07-24 01:49:54,272 INFO mapreduce.Job:  map 75% reduce 0%
# 2022-07-24 01:49:55,285 INFO mapreduce.Job:  map 100% reduce 0%
# 2022-07-24 01:49:56,303 INFO mapreduce.Job: Job job_1658206934431_2413 completed successfully
# 2022-07-24 01:49:56,367 INFO mapreduce.Job: Counters: 33
#         File System Counters
#                 FILE: Number of bytes read=0
#                 FILE: Number of bytes written=1102312
#                 FILE: Number of read operations=0
#                 FILE: Number of large read operations=0
#                 FILE: Number of write operations=0
#                 HDFS: Number of bytes read=424
#                 HDFS: Number of bytes written=83097
#                 HDFS: Number of read operations=24
#                 HDFS: Number of large read operations=0
#                 HDFS: Number of write operations=8
#                 HDFS: Number of bytes read erasure-coded=0
#         Job Counters
#                 Launched map tasks=4
#                 Other local map tasks=4
#                 Total time spent by all maps in occupied slots (ms)=7000
#                 Total time spent by all reduces in occupied slots (ms)=0
#                 Total time spent by all map tasks (ms)=7000
#                 Total vcore-milliseconds taken by all map tasks=7000
#                 Total megabyte-milliseconds taken by all map tasks=7168000
#         Map-Reduce Framework
#                 Map input records=2390
#                 Map output records=2390
#                 Input split bytes=424
#                 Spilled Records=0
#                 Failed Shuffles=0
#                 Merged Map outputs=0
#                 GC time elapsed (ms)=93
#                 CPU time spent (ms)=2400
#                 Physical memory (bytes) snapshot=1247379456
#                 Virtual memory (bytes) snapshot=10497810432
#                 Total committed heap usage (bytes)=2516582400
#                 Peak Map Physical memory (bytes)=322764800
#                 Peak Map Virtual memory (bytes)=2627432448
#         File Input Format Counters
#                 Bytes Read=0
#         File Output Format Counters
#                 Bytes Written=83097
# 2022-07-24 01:49:56,370 INFO mapreduce.ImportJobBase: Transferred 81.1494 KB in 19.6388 seconds (4.1321 KB/sec)
# 2022-07-24 01:49:56,372 INFO mapreduce.ImportJobBase: Retrieved 2390 records.
# 2022-07-24 01:49:56,382 INFO util.AppendUtils: Creating missing output directory - itv002768_covid19_india
# 2022-07-24 01:49:56,590 INFO tool.ImportTool: Saving incremental import state to the metastore
# 2022-07-24 01:49:56,621 INFO tool.ImportTool: Updated data for job: load_covid_info_india
# [itv002768@g02 ~]$ sqoop job --exec load_covid_testing_data
# Warning: /opt/sqoop/../hcatalog does not exist! HCatalog jobs will fail.
# Please set $HCAT_HOME to the root of your HCatalog installation.
# Warning: /opt/sqoop/../accumulo does not exist! Accumulo imports will fail.
# Please set $ACCUMULO_HOME to the root of your Accumulo installation.
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hadoop-3.3.0/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/apache-hive-3.1.2-bin/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# 2022-07-24 01:50:28,271 INFO sqoop.Sqoop: Running Sqoop version: 1.4.7
# 2022-07-24 01:50:30,689 INFO manager.MySQLManager: Preparing to use a MySQL streaming resultset.
# 2022-07-24 01:50:30,689 INFO tool.CodeGenTool: Beginning code generation
# 2022-07-24 01:50:30,989 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `itv002768_state_wise_testing` AS t LIMIT 1
# 2022-07-24 01:50:31,050 INFO manager.SqlManager: Executing SQL statement: SELECT t.* FROM `itv002768_state_wise_testing` AS t LIMIT 1
# 2022-07-24 01:50:31,054 INFO orm.CompilationManager: HADOOP_MAPRED_HOME is /opt/hadoop
# Note: /tmp/sqoop-itv002768/compile/beadee95fc14bef66419cfcf9c4a7b37/itv002768_state_wise_testing.java uses or overrides a deprecated API.
# Note: Recompile with -Xlint:deprecation for details.
# 2022-07-24 01:50:34,278 INFO orm.CompilationManager: Writing jar file: /tmp/sqoop-itv002768/compile/beadee95fc14bef66419cfcf9c4a7b37/itv002768_state_wise_testing.jar
# 2022-07-24 01:50:34,284 INFO tool.ImportTool: Maximal id query for free form incremental import: SELECT MAX(`seq`) FROM `itv002768_state_wise_testing`
# 2022-07-24 01:50:34,284 INFO tool.ImportTool: Incremental import based on column `seq`
# 2022-07-24 01:50:34,284 INFO tool.ImportTool: Upper bound value: 1922
# 2022-07-24 01:50:34,284 WARN manager.MySQLManager: It looks like you are importing from mysql.
# 2022-07-24 01:50:34,284 WARN manager.MySQLManager: This transfer can be faster! Use the --direct
# 2022-07-24 01:50:34,284 WARN manager.MySQLManager: option to exercise a MySQL-specific fast path.
# 2022-07-24 01:50:34,284 INFO manager.MySQLManager: Setting zero DATETIME behavior to convertToNull (mysql)
# 2022-07-24 01:50:34,286 INFO mapreduce.ImportJobBase: Beginning import of itv002768_state_wise_testing
# 2022-07-24 01:50:34,287 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2022-07-24 01:50:34,306 INFO Configuration.deprecation: mapred.jar is deprecated. Instead, use mapreduce.job.jar
# 2022-07-24 01:50:34,828 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2022-07-24 01:50:35,260 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at m02.itversity.com/172.16.1.104:8032
# 2022-07-24 01:50:35,616 INFO client.AHSProxy: Connecting to Application History server at m01.itversity.com/172.16.1.103:10200
# 2022-07-24 01:50:36,018 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/itv002768/.staging/job_1658206934431_2416
# 2022-07-24 01:50:40,026 INFO db.DBInputFormat: Using read commited transaction isolation
# 2022-07-24 01:50:40,026 INFO db.DataDrivenDBInputFormat: BoundingValsQuery: SELECT MIN(`seq`), MAX(`seq`) FROM `itv002768_state_wise_testing` WHERE ( `seq` <= 1922 )
# 2022-07-24 01:50:40,028 INFO db.IntegerSplitter: Split size: 480; Num splits: 4 from: 1 to: 1922
# 2022-07-24 01:50:40,240 INFO mapreduce.JobSubmitter: number of splits:4
# 2022-07-24 01:50:40,727 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1658206934431_2416
# 2022-07-24 01:50:40,728 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2022-07-24 01:50:40,970 INFO conf.Configuration: resource-types.xml not found
# 2022-07-24 01:50:40,970 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.
# 2022-07-24 01:50:41,042 INFO impl.YarnClientImpl: Submitted application application_1658206934431_2416
# 2022-07-24 01:50:41,065 INFO mapreduce.Job: The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2416/
# 2022-07-24 01:50:41,065 INFO mapreduce.Job: Running job: job_1658206934431_2416
# 2022-07-24 01:50:45,176 INFO mapreduce.Job: Job job_1658206934431_2416 running in uber mode : false
# 2022-07-24 01:50:45,197 INFO mapreduce.Job:  map 0% reduce 0%
# 2022-07-24 01:50:49,262 INFO mapreduce.Job:  map 75% reduce 0%
# 2022-07-24 01:50:50,274 INFO mapreduce.Job:  map 100% reduce 0%
# 2022-07-24 01:50:50,289 INFO mapreduce.Job: Job job_1658206934431_2416 completed successfully
# 2022-07-24 01:50:50,371 INFO mapreduce.Job: Counters: 33
#         File System Counters
#                 FILE: Number of bytes read=0
#                 FILE: Number of bytes written=1102432
#                 FILE: Number of read operations=0
#                 FILE: Number of large read operations=0
#                 FILE: Number of write operations=0
#                 HDFS: Number of bytes read=418
#                 HDFS: Number of bytes written=77113
#                 HDFS: Number of read operations=24
#                 HDFS: Number of large read operations=0
#                 HDFS: Number of write operations=8
#                 HDFS: Number of bytes read erasure-coded=0
#         Job Counters
#                 Launched map tasks=4
#                 Other local map tasks=4
#                 Total time spent by all maps in occupied slots (ms)=6597
#                 Total time spent by all reduces in occupied slots (ms)=0
#                 Total time spent by all map tasks (ms)=6597
#                 Total vcore-milliseconds taken by all map tasks=6597
#                 Total megabyte-milliseconds taken by all map tasks=6755328
#         Map-Reduce Framework
#                 Map input records=1922
#                 Map output records=1922
#                 Input split bytes=418
#                 Spilled Records=0
#                 Failed Shuffles=0
#                 Merged Map outputs=0
#                 GC time elapsed (ms)=80
#                 CPU time spent (ms)=2450
#                 Physical memory (bytes) snapshot=1226432512
#                 Virtual memory (bytes) snapshot=10497941504
#                 Total committed heap usage (bytes)=2490368000
#                 Peak Map Physical memory (bytes)=308396032
#                 Peak Map Virtual memory (bytes)=2626744320
#         File Input Format Counters
#                 Bytes Read=0
#         File Output Format Counters
#                 Bytes Written=77113
# 2022-07-24 01:50:50,375 INFO mapreduce.ImportJobBase: Transferred 75.3057 KB in 15.5413 seconds (4.8455 KB/sec)
# 2022-07-24 01:50:50,377 INFO mapreduce.ImportJobBase: Retrieved 1922 records.
# 2022-07-24 01:50:50,386 INFO util.AppendUtils: Creating missing output directory - itv002768_state_wise_testing
# 2022-07-24 01:50:50,542 INFO tool.ImportTool: Saving incremental import state to the metastore
# 2022-07-24 01:50:50,580 INFO tool.ImportTool: Updated data for job: load_covid_testing_data
#
# [itv002768@g02 ~]$ hadoop fs -ls week5_assignment_hadoop_data
# Found 2 items
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 01:49 week5_assignment_hadoop_data/itv002768_covid19_india
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 01:50 week5_assignment_hadoop_data/itv002768_state_wise_testing
# [itv002768@g02 ~]$ hadoop fs -ls week5_assignment_hadoop_data/itv002768_covid19_india
# Found 4 items
# -rw-r--r--   3 itv002768 supergroup      19264 2022-07-24 01:49 week5_assignment_hadoop_data/itv002768_covid19_india/part-m-00000
# -rw-r--r--   3 itv002768 supergroup      20454 2022-07-24 01:49 week5_assignment_hadoop_data/itv002768_covid19_india/part-m-00001
# -rw-r--r--   3 itv002768 supergroup      21396 2022-07-24 01:49 week5_assignment_hadoop_data/itv002768_covid19_india/part-m-00002
# -rw-r--r--   3 itv002768 supergroup      21983 2022-07-24 01:49 week5_assignment_hadoop_data/itv002768_covid19_india/part-m-00003
# [itv002768@g02 ~]$ hadoop fs -ls week5_assignment_hadoop_data/itv002768_state_wise_testing
# Found 4 items
# -rw-r--r--   3 itv002768 supergroup      19443 2022-07-24 01:50 week5_assignment_hadoop_data/itv002768_state_wise_testing/part-m-00000
# -rw-r--r--   3 itv002768 supergroup      19266 2022-07-24 01:50 week5_assignment_hadoop_data/itv002768_state_wise_testing/part-m-00001
# -rw-r--r--   3 itv002768 supergroup      18589 2022-07-24 01:50 week5_assignment_hadoop_data/itv002768_state_wise_testing/part-m-00002
# -rw-r--r--   3 itv002768 supergroup      19815 2022-07-24 01:50 week5_assignment_hadoop_data/itv002768_state_wise_testing/part-m-00003
# ```

# %% [markdown]
# #### Create and Load data in Hive
#
# ```shell
# hive> create database if not exists covid_india;
# OK
# Time taken: 0.165 seconds
# hive> use covid_india;
# OK
#
# hive> create external table if not exists state_testing_itv002768(`seq` int,
#     >   `date_time` string,
#     >   `state` string,
#     >   `total_samples` int,
#     >   `negative` int,
#     >   `positive` int
#     > )
#     > row format delimited
#     > fields terminated by ','
#     > stored as textfile
#     > location '/user/itv002768/week5_assignment_hadoop_data/itv002768_state_wise_testing';
# OK
# Time taken: 0.117 seconds
# hive> select count(*) from state_testing_itv002768;
# Query ID = itv002768_20220724025002_96b7f5ff-958a-4f8f-bb30-af4210537ef6
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1658206934431_2454, Tracking URL = http://m02.itversity.com:19088/proxy/application_1658206934431_2454/
# Kill Command = /opt/hadoop/bin/mapred job  -kill job_1658206934431_2454
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2022-07-24 02:50:16,911 Stage-1 map = 0%,  reduce = 0%
# 2022-07-24 02:50:20,119 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 1.72 sec
# 2022-07-24 02:50:24,301 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 3.6 sec
# MapReduce Total cumulative CPU time: 3 seconds 600 msec
# Ended Job = job_1658206934431_2454
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 3.6 sec   HDFS Read: 90798 HDFS Write: 104 SUCCESS
# Total MapReduce CPU Time Spent: 3 seconds 600 msec
# OK
# 1922
# Time taken: 23.095 seconds, Fetched: 1 row(s)
#
# hive> create external table if not exists covid_india_itv002768(
#     > `sno` int,
#     > `date_time` string,
#     > `state` string,
#     > `cured` int,
#     > `death` int,
#     > `confirmed` int)
#     > row format delimited
#     > fields terminated by ','
#     > stored as textfile
#     > location '/user/itv002768/week5_assignment_hadoop_data/itv002768_covid19_india';
# OK
# Time taken: 0.268 seconds
# hive> select count(*) from covid_india_itv002768;
# Query ID = itv002768_20220724025615_0f10b690-199a-4821-924a-f4b6ac10d834
# Total jobs = 1
# Launching Job 1 out of 1
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1658206934431_2459, Tracking URL = http://m02.itversity.com:19088/proxy/application_1658206934431_2459/
# Kill Command = /opt/hadoop/bin/mapred job  -kill job_1658206934431_2459
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2022-07-24 02:56:34,691 Stage-1 map = 0%,  reduce = 0%
# 2022-07-24 02:56:37,818 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 1.89 sec
# 2022-07-24 02:56:41,934 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 3.47 sec
# MapReduce Total cumulative CPU time: 3 seconds 470 msec
# Ended Job = job_1658206934431_2459
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 3.47 sec   HDFS Read: 96632 HDFS Write: 104 SUCCESS
# Total MapReduce CPU Time Spent: 3 seconds 470 msec
# OK
# 2390
# Time taken: 28.465 seconds, Fetched: 1 row(s)

# %% [markdown]
# ### Optimizations
# ```shell
# [itv002768@g02 ~]$ hadoop fs -mkdir /user/itv002768/partition_testing
# [itv002768@g02 ~]$ hadoop fs -mkdir /user/itv002768/partition_covid_india
#
# 0: jdbc:hive2://m02.itversity.com:10000/> set hive.exec.dynamic.partition=true;
# No rows affected (0.008 seconds)
# 0: jdbc:hive2://m02.itversity.com:10000/> set hive.exec.dynamic.partition.mode=nonstrict;
# No rows affected (0.007 seconds)
# 0: jdbc:hive2://m02.itversity.com:10000/> set hive.enforce.bucketing=true;
# No rows affected (0.007 seconds)
#
# 0: jdbc:hive2://m02.itversity.com:10000/> create external table if not exists state_testing_itv002768_orc(`seq` int,
# . . . . . . . . . . . . . . . . . . . . >   `date_time` date,
# . . . . . . . . . . . . . . . . . . . . >   `total_samples` int,
# . . . . . . . . . . . . . . . . . . . . >   `negative` int,
# . . . . . . . . . . . . . . . . . . . . >   `positive` int
# . . . . . . . . . . . . . . . . . . . . > )
# . . . . . . . . . . . . . . . . . . . . > partitioned by (state string)
# . . . . . . . . . . . . . . . . . . . . > clustered by (date_time) into 4 buckets
# . . . . . . . . . . . . . . . . . . . . > stored as orc
# . . . . . . . . . . . . . . . . . . . . > location '/user/itv002768/partition_testing'
# . . . . . . . . . . . . . . . . . . . . > TBLPROPERTIES('orc.compress'='snappy');
# INFO  : Compiling command(queryId=hive_20220724035648_324c2e87-f2f2-4bf5-857c-d56e1c316f97): create external table if not exists state_testing_itv002768_orc(`seq` int,
# `date_time` date,
# `total_samples` int,
# `negative` int,
# `positive` int
# )
# partitioned by (state string)
# clustered by (date_time) into 4 buckets
# stored as orc
# location '/user/itv002768/partition_testing'
# TBLPROPERTIES('orc.compress'='snappy')
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hive_20220724035648_324c2e87-f2f2-4bf5-857c-d56e1c316f97); Time taken: 0.041 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20220724035648_324c2e87-f2f2-4bf5-857c-d56e1c316f97): create external table if not exists state_testing_itv002768_orc(`seq` int,
# `date_time` date,
# `total_samples` int,
# `negative` int,
# `positive` int
# )
# partitioned by (state string)
# clustered by (date_time) into 4 buckets
# stored as orc
# location '/user/itv002768/partition_testing'
# TBLPROPERTIES('orc.compress'='snappy')
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hive_20220724035648_324c2e87-f2f2-4bf5-857c-d56e1c316f97); Time taken: 0.053 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.109 seconds)
#
# 0: jdbc:hive2://m02.itversity.com:10000/> insert overwrite table state_testing_itv002768_orc
# . . . . . . . . . . . . . . . . . . . . > partition (state)
# . . . . . . . . . . . . . . . . . . . . > select seq, from_unixtime(unix_timestamp(date_time, 'M/dd/yyyy'),'yyyy-MM-dd'),
# . . . . . . . . . . . . . . . . . . . . > total_samples, negative, positive, state
# . . . . . . . . . . . . . . . . . . . . > from state_testing_itv002768;
# INFO  : Compiling command(queryId=hive_20220724040001_0b9bff3f-d7ad-4757-b780-b8280b35c549): insert overwrite table state_testing_itv002768_orc
# partition (state)
# select seq, from_unixtime(unix_timestamp(date_time, 'M/dd/yyyy'),'yyyy-MM-dd'),
# total_samples, negative, positive, state
# from state_testing_itv002768
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:_col0, type:int, comment:null), FieldSchema(name:_col1, type:date, comment:null), FieldSchema(name:_col2, type:int, comment:null), FieldSchema(name:_col3, type:int, comment:null), FieldSchema(name:_col4, type:int, comment:null), FieldSchema(name:_col5, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20220724040001_0b9bff3f-d7ad-4757-b780-b8280b35c549); Time taken: 5.369 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20220724040001_0b9bff3f-d7ad-4757-b780-b8280b35c549): insert overwrite table state_testing_itv002768_orc
# partition (state)
# select seq, from_unixtime(unix_timestamp(date_time, 'M/dd/yyyy'),'yyyy-MM-dd'),
# total_samples, negative, positive, state
# from state_testing_itv002768
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hive_20220724040001_0b9bff3f-d7ad-4757-b780-b8280b35c549
# INFO  : Total jobs = 1
# INFO  : Launching Job 1 out of 1
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 4
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1658206934431_2493
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2493/
# INFO  : Starting Job = job_1658206934431_2493, Tracking URL = http://m02.itversity.com:19088/proxy/application_1658206934431_2493/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1658206934431_2493
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 4
# INFO  : 2022-07-24 04:00:14,491 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2022-07-24 04:00:19,668 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 2.79 sec
# INFO  : 2022-07-24 04:00:30,886 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 21.8 sec
# INFO  : MapReduce Total cumulative CPU time: 21 seconds 800 msec
# INFO  : Ended Job = job_1658206934431_2493
# INFO  : Starting task [Stage-0:MOVE] in serial mode
# INFO  : Loading data to table covid_india.state_testing_itv002768_orc partition (state=null) from hdfs://m01.itversity.com:9000/user/itv002768/partition_testing/.hive-staging_hive_2022-07-24_04-00-01_456_4514674185456005769-5/-ext-10000
# INFO  :
#
# INFO  :          Time taken to load dynamic partitions: 1.797 seconds
# INFO  :          Time taken for adding to write entity : 0.001 seconds
# INFO  : Starting task [Stage-2:STATS] in serial mode
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1  Reduce: 4   Cumulative CPU: 21.8 sec   HDFS Read: 114556 HDFS Write: 109493 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 21 seconds 800 msec
# INFO  : Completed executing command(queryId=hive_20220724040001_0b9bff3f-d7ad-4757-b780-b8280b35c549); Time taken: 27.538 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (32.917 seconds)
#
# 0: jdbc:hive2://m02.itversity.com:10000/> select count(*) from state_testing_itv002768_orc;
# INFO  : Compiling command(queryId=hive_20220724040153_7b7cf3e2-52d4-48f5-970d-e2f199780923): select count(*) from state_testing_itv002768_orc
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:_c0, type:bigint, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20220724040153_7b7cf3e2-52d4-48f5-970d-e2f199780923); Time taken: 4.665 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20220724040153_7b7cf3e2-52d4-48f5-970d-e2f199780923): select count(*) from state_testing_itv002768_orc
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hive_20220724040153_7b7cf3e2-52d4-48f5-970d-e2f199780923
# INFO  : Total jobs = 1
# INFO  : Launching Job 1 out of 1
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1658206934431_2494
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2494/
# INFO  : Starting Job = job_1658206934431_2494, Tracking URL = http://m02.itversity.com:19088/proxy/application_1658206934431_2494/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1658206934431_2494
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# INFO  : 2022-07-24 04:02:06,961 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2022-07-24 04:02:11,061 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 4.08 sec
# INFO  : 2022-07-24 04:02:16,181 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 5.56 sec
# INFO  : MapReduce Total cumulative CPU time: 5 seconds 560 msec
# INFO  : Ended Job = job_1658206934431_2494
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 5.56 sec   HDFS Read: 152668 HDFS Write: 104 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 5 seconds 560 msec
# INFO  : Completed executing command(queryId=hive_20220724040153_7b7cf3e2-52d4-48f5-970d-e2f199780923); Time taken: 19.043 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +-------+
# |  _c0  |
# +-------+
# | 1922  |
# +-------+
#
# [itv002768@g02 ~]$ hadoop fs -ls /user/itv002768/partition_testing
# Found 35 items
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Andaman and Nicobar Islands
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Andhra Pradesh
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Arunachal Pradesh
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Assam
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Bihar
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Chandigarh
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Chhattisgarh
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Dadra and Nagar Haveli
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Delhi
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Goa
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Gujarat
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Haryana
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Himachal Pradesh
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Jammu and Kashmir
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Jharkhand
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Karnataka
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Kerala
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Ladakh
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Madhya Pradesh
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Maharashtra
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Manipur
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Meghalaya
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Mizoram
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Nagaland
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Odisha
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Puducherry
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Punjab
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Rajasthan
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Sikkim
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Tamil Nadu
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Telangana
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Tripura
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Uttar Pradesh
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=Uttarakhand
# drwxr-xr-x   - itv002768 supergroup          0 2022-07-24 04:00 /user/itv002768/partition_testing/state=West Bengal
#
# [itv002768@g02 ~]$ hadoop fs -ls /user/itv002768/partition_testing/state=Chandigarh
# Found 4 items
# -rw-r--r--   3 itv002768 supergroup        731 2022-07-24 04:00 /user/itv002768/partition_testing/state=Chandigarh/000000_0
# -rw-r--r--   3 itv002768 supergroup        679 2022-07-24 04:00 /user/itv002768/partition_testing/state=Chandigarh/000001_0
# -rw-r--r--   3 itv002768 supergroup        722 2022-07-24 04:00 /user/itv002768/partition_testing/state=Chandigarh/000002_0
# -rw-r--r--   3 itv002768 supergroup        731 2022-07-24 04:00 /user/itv002768/partition_testing/state=Chandigarh/000003_0
#
# 0: jdbc:hive2://m02.itversity.com:10000/> create external table if not exists covid_india_itv002768_orc(`sno` int,
# . . . . . . . . . . . . . . . . . . . . > `date_time` date,
# . . . . . . . . . . . . . . . . . . . . > `cured` int,
# . . . . . . . . . . . . . . . . . . . . > `death` int,
# . . . . . . . . . . . . . . . . . . . . > `confirmed` int)
# . . . . . . . . . . . . . . . . . . . . > partitioned by (state string)
# . . . . . . . . . . . . . . . . . . . . > clustered by (date_time) into 4 buckets
# . . . . . . . . . . . . . . . . . . . . > stored as orc
# . . . . . . . . . . . . . . . . . . . . > location '/user/itv002768/partition_covid_india'
# . . . . . . . . . . . . . . . . . . . . > TBLPROPERTIES('orc.compress'='snappy');
# INFO  : Compiling command(queryId=hive_20220724040839_3105b5d6-e4d1-4513-80a4-b027a794fe03): create external table if not exists covid_india_itv002768_orc(`sno` int,
# `date_time` date,
# `cured` int,
# `death` int,
# `confirmed` int)
# partitioned by (state string)
# clustered by (date_time) into 4 buckets
# stored as orc
# location '/user/itv002768/partition_covid_india'
# TBLPROPERTIES('orc.compress'='snappy')
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hive_20220724040839_3105b5d6-e4d1-4513-80a4-b027a794fe03); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20220724040839_3105b5d6-e4d1-4513-80a4-b027a794fe03): create external table if not exists covid_india_itv002768_orc(`sno` int,
# `date_time` date,
# `cured` int,
# `death` int,
# `confirmed` int)
# partitioned by (state string)
# clustered by (date_time) into 4 buckets
# stored as orc
# location '/user/itv002768/partition_covid_india'
# TBLPROPERTIES('orc.compress'='snappy')
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hive_20220724040839_3105b5d6-e4d1-4513-80a4-b027a794fe03); Time taken: 0.054 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.081 seconds)
#
# 0: jdbc:hive2://m02.itversity.com:10000/> insert overwrite table covid_india_itv002768_orc
# . . . . . . . . . . . . . . . . . . . . > partition (state)
# . . . . . . . . . . . . . . . . . . . . > select sno, from_unixtime(unix_timestamp(date_time, 'M/dd/yyyy'),'yyyy-MM-dd'),
# . . . . . . . . . . . . . . . . . . . . > cured, death, confirmed, state
# . . . . . . . . . . . . . . . . . . . . > from covid_india_itv002768;
# INFO  : Compiling command(queryId=hive_20220724041415_931c00dd-6b30-41fc-9f45-00aca064c01f): insert overwrite table covid_india_itv002768_orc
# partition (state)
# select sno, from_unixtime(unix_timestamp(date_time, 'M/dd/yyyy'),'yyyy-MM-dd'),
# cured, death, confirmed, state
# from covid_india_itv002768
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:_col0, type:int, comment:null), FieldSchema(name:_col1, type:date, comment:null), FieldSchema(name:_col2, type:int, comment:null), FieldSchema(name:_col3, type:int, comment:null), FieldSchema(name:_col4, type:int, comment:null), FieldSchema(name:_col5, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20220724041415_931c00dd-6b30-41fc-9f45-00aca064c01f); Time taken: 4.574 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20220724041415_931c00dd-6b30-41fc-9f45-00aca064c01f): insert overwrite table covid_india_itv002768_orc
# partition (state)
# select sno, from_unixtime(unix_timestamp(date_time, 'M/dd/yyyy'),'yyyy-MM-dd'),
# cured, death, confirmed, state
# from covid_india_itv002768
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hive_20220724041415_931c00dd-6b30-41fc-9f45-00aca064c01f
# INFO  : Total jobs = 1
# INFO  : Launching Job 1 out of 1
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 4
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1658206934431_2501
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2501/
# INFO  : Starting Job = job_1658206934431_2501, Tracking URL = http://m02.itversity.com:19088/proxy/application_1658206934431_2501/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1658206934431_2501
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 4
# INFO  : 2022-07-24 04:14:27,506 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2022-07-24 04:14:32,625 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.3 sec
# INFO  : 2022-07-24 04:14:47,010 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 22.31 sec
# INFO  : MapReduce Total cumulative CPU time: 22 seconds 310 msec
# INFO  : Ended Job = job_1658206934431_2501
# INFO  : Starting task [Stage-0:MOVE] in serial mode
# INFO  : Loading data to table covid_india.covid_india_itv002768_orc partition (state=null) from hdfs://m01.itversity.com:9000/user/itv002768/partition_covid_india/.hive-staging_hive_2022-07-24_04-14-15_890_4414832020707566595-5/-ext-10000
# INFO  :
#
# INFO  :          Time taken to load dynamic partitions: 1.712 seconds
# INFO  :          Time taken for adding to write entity : 0.006 seconds
# INFO  : Starting task [Stage-2:STATS] in serial mode
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1  Reduce: 4   Cumulative CPU: 22.31 sec   HDFS Read: 120271 HDFS Write: 116500 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 22 seconds 310 msec
# INFO  : Completed executing command(queryId=hive_20220724041415_931c00dd-6b30-41fc-9f45-00aca064c01f); Time taken: 31.214 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (35.796 seconds)
#
# 0: jdbc:hive2://m02.itversity.com:10000/> select count(*) from covid_india_itv002768_orc;
# INFO  : Compiling command(queryId=hive_20220724041531_f55b6796-3a50-4d47-a28d-99161f51f5f9): select count(*) from covid_india_itv002768_orc
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:_c0, type:bigint, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20220724041531_f55b6796-3a50-4d47-a28d-99161f51f5f9); Time taken: 5.943 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20220724041531_f55b6796-3a50-4d47-a28d-99161f51f5f9): select count(*) from covid_india_itv002768_orc
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hive_20220724041531_f55b6796-3a50-4d47-a28d-99161f51f5f9
# INFO  : Total jobs = 1
# INFO  : Launching Job 1 out of 1
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1658206934431_2502
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2502/
# INFO  : Starting Job = job_1658206934431_2502, Tracking URL = http://m02.itversity.com:19088/proxy/application_1658206934431_2502/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1658206934431_2502
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# INFO  : 2022-07-24 04:15:44,347 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2022-07-24 04:15:49,462 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 4.11 sec
# INFO  : 2022-07-24 04:15:53,553 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 5.57 sec
# INFO  : MapReduce Total cumulative CPU time: 5 seconds 570 msec
# INFO  : Ended Job = job_1658206934431_2502
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 5.57 sec   HDFS Read: 162122 HDFS Write: 104 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 5 seconds 570 msec
# INFO  : Completed executing command(queryId=hive_20220724041531_f55b6796-3a50-4d47-a28d-99161f51f5f9); Time taken: 17.619 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +-------+
# |  _c0  |
# +-------+
# | 2390  |
# +-------+
# 1 row selected (23.593 seconds)
# ```

# %% [markdown]
# ### Perform Mapside join
#
# ```shell
# 0: jdbc:hive2://m02.itversity.com:10000/> set hive.auto.convert.join=false;
# No rows affected (0.008 seconds)
# 0: jdbc:hive2://m02.itversity.com:10000/> set hive.ignore.mapjoin.hint=false;
# No rows affected (0.005 seconds)
#
# 0: jdbc:hive2://m02.itversity.com:10000/> select /* +MAPJOIN(t) */ t.date_time, t.total_samples, t.negative, t.positive, t.state, ci.confirmed, ci.cured, ci.death
# . . . . . . . . . . . . . . . . . . . . > from state_testing_itv002768_orc t join covid_india_itv002768_orc ci
# . . . . . . . . . . . . . . . . . . . . > on t.date_time=ci.date_time and t.state=ci.state limit 100;
# INFO  : Compiling command(queryId=hive_20220724043117_73a701b4-3473-4808-adec-37ee45deb6f9): select /* +MAPJOIN(t) */ t.date_time, t.total_samples, t.negative, t.positive, t.state, ci.confirmed, ci.cured, ci.death
# from state_testing_itv002768_orc t join covid_india_itv002768_orc ci
# on t.date_time=ci.date_time and t.state=ci.state limit 100
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:t.date_time, type:date, comment:null), FieldSchema(name:t.total_samples, type:int, comment:null), FieldSchema(name:t.negative, type:int, comment:null), FieldSchema(name:t.positive, type:int, comment:null), FieldSchema(name:t.state, type:string, comment:null), FieldSchema(name:ci.confirmed, type:int, comment:null), FieldSchema(name:ci.cured, type:int, comment:null), FieldSchema(name:ci.death, type:int, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20220724043117_73a701b4-3473-4808-adec-37ee45deb6f9); Time taken: 6.201 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20220724043117_73a701b4-3473-4808-adec-37ee45deb6f9): select /* +MAPJOIN(t) */ t.date_time, t.total_samples, t.negative, t.positive, t.state, ci.confirmed, ci.cured, ci.death
# from state_testing_itv002768_orc t join covid_india_itv002768_orc ci
# on t.date_time=ci.date_time and t.state=ci.state limit 100
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hive_20220724043117_73a701b4-3473-4808-adec-37ee45deb6f9
# INFO  : Total jobs = 1
# INFO  : Launching Job 1 out of 1
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:2
# INFO  : Submitting tokens for job: job_1658206934431_2507
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://m02.itversity.com:19088/proxy/application_1658206934431_2507/
# INFO  : Starting Job = job_1658206934431_2507, Tracking URL = http://m02.itversity.com:19088/proxy/application_1658206934431_2507/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1658206934431_2507
# INFO  : Hadoop job information for Stage-1: number of mappers: 2; number of reducers: 1
# INFO  : 2022-07-24 04:31:31,809 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2022-07-24 04:31:36,932 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 10.58 sec
# INFO  : 2022-07-24 04:31:42,059 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 12.28 sec
# INFO  : MapReduce Total cumulative CPU time: 12 seconds 280 msec
# INFO  : Ended Job = job_1658206934431_2507
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 2  Reduce: 1   Cumulative CPU: 12.28 sec   HDFS Read: 367215 HDFS Write: 5908 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 12 seconds 280 msec
# INFO  : Completed executing command(queryId=hive_20220724043117_73a701b4-3473-4808-adec-37ee45deb6f9); Time taken: 19.819 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------+------------------+-------------+-------------+-------------------------+---------------+-----------+-----------+
# | t.date_time  | t.total_samples  | t.negative  | t.positive  |         t.state         | ci.confirmed  | ci.cured  | ci.death  |
# +--------------+------------------+-------------+-------------+-------------------------+---------------+-----------+-----------+
# | 2020-04-04   | 9744             | 8586        | 306         | Kerala                  | 295           | 41        | 2         |
# | 2020-04-04   | 1042             | NULL        | NULL        | West Bengal             | 69            | 3         | 3         |
# | 2020-04-05   | 3037             | 2299        | 32          | Bihar                   | 517           | 125       | 4         |
# | 2020-04-05   | 1551             | 1429        | 106         | Jammu and Kashmir       | 701           | 287       | 8         |
# | 2020-04-05   | 10221            | 9300        | 314         | Kerala                  | 500           | 401       | 4         |
# | 2020-04-05   | 2812             | 1954        | 193         | Madhya Pradesh          | 2942          | 798       | 165       |
# | 2020-04-05   | 16008            | 14837       | NULL        | Maharashtra             | 12974         | 2115      | 548       |
# | 2020-04-05   | 12279            | 11439       | 260         | Rajasthan               | 2886          | 1356      | 71        |
# | 2020-04-05   | 5255             | 4796        | 278         | Uttar Pradesh           | 2742          | 758       | 45        |
# | 2020-04-05   | 5255             | 4796        | 278         | Uttar Pradesh           | 2742          | 758       | 45        |
# | 2020-04-06   | 10716            | 9607        | 327         | Kerala                  | 1494          | 651       | 11        |
# | 2020-04-06   | 17563            | 15808       | 868         | Maharashtra             | 74860         | 32329     | 2587      |
# | 2020-04-06   | 58               | 0           | 1           | Mizoram                 | 14            | 1         | 0         |
# | 2020-04-06   | 60               | 47          | 0           | Nagaland                | 58            | 0         | 0         |
# | 2020-04-06   | 1301             | NULL        | NULL        | West Bengal             | 6508          | 2580      | 345       |
# | 2020-05-04   | 125229           | 123579      | 1650        | Andhra Pradesh          | 190           | 1         | 1         |
# | 2020-05-04   | 869              | 762         | 2           | Arunachal Pradesh       | 1             | 0         | 0         |
# | 2020-05-04   | 12775            | 11764       | 42          | Assam                   | 26            | 0         | 0         |
# | 2020-05-04   | 28345            | NULL        | 525         | Bihar                   | 30            | 0         | 1         |
# | 2020-05-04   | 1678             | 1545        | 102         | Chandigarh              | 18            | 0         | 0         |
# | 2020-05-04   | 64108            | NULL        | 4898        | Delhi                   | 503           | 18        | 7         |
# | 2020-05-04   | 2899             | NULL        | 7           | Goa                     | 7             | 0         | 0         |
# | 2020-05-04   | 84648            | 78844       | 5804        | Gujarat                 | 122           | 18        | 11        |
# | 2020-05-04   | 38183            | 34501       | 517         | Haryana                 | 59            | 25        | 1         |
# | 2020-05-04   | 7430             | 7320        | 41          | Himachal Pradesh        | 6             | 1         | 1         |
# | 2020-05-04   | 28199            | 27473       | 726         | Jammu and Kashmir       | 106           | 4         | 2         |
# | 2020-05-04   | 13832            | 13717       | 115         | Jharkhand               | 3             | 0         | 0         |
# | 2020-05-04   | 79193            | 74664       | 651         | Karnataka               | 144           | 12        | 4         |
# | 2020-05-04   | 35441            | 34161       | 499         | Kerala                  | 306           | 49        | 2         |
# | 2020-05-04   | 2639             | 1879        | 41          | Ladakh                  | 14            | 10        | 0         |
# | 2020-05-04   | 52095            | 46634       | 2942        | Madhya Pradesh          | 165           | 0         | 9         |
# | 2020-05-04   | 168374           | 156078      | 12974       | Maharashtra             | 490           | 42        | 24        |
# | 2020-05-04   | 571              | NULL        | 2           | Manipur                 | 2             | 0         | 0         |
# | 2020-05-04   | 183              | NULL        | 1           | Mizoram                 | 1             | 0         | 0         |
# | 2020-05-04   | 41128            | NULL        | 169         | Odisha                  | 20            | 0         | 0         |
# | 2020-05-04   | 3281             | 3220        | 12          | Puducherry              | 5             | 1         | 0         |
# | 2020-05-04   | 28545            | 21295       | 1232        | Punjab                  | 57            | 1         | 5         |
# | 2020-05-04   | 129258           | 122513      | 3061        | Rajasthan               | 200           | 21        | 0         |
# | 2020-05-04   | 162970           | 158558      | 3550        | Tamil Nadu              | 485           | 6         | 3         |
# | 2020-05-04   | 98300            | 94682       | 2766        | Uttar Pradesh           | 227           | 19        | 2         |
# | 2020-05-04   | 7806             | 7134        | 60          | Uttarakhand             | 22            | 2         | 0         |
# | 2020-05-04   | 25116            | NULL        | 1259        | West Bengal             | 80            | 10        | 3         |
# | 2020-05-05   | 133492           | 131775      | 1717        | Andhra Pradesh          | 1717          | 589       | 36        |
# | 2020-05-05   | 970              | 814         | 2           | Arunachal Pradesh       | 1             | 1         | 0         |
# | 2020-05-05   | 13442            | 12533       | 43          | Assam                   | 43            | 32        | 1         |
# | 2020-05-05   | 28791            | NULL        | 529         | Bihar                   | 529           | 130       | 4         |
# | 2020-05-05   | 1713             | 1576        | 115         | Chandigarh              | 102           | 21        | 1         |
# | 2020-05-05   | 21323            | 20300       | 58          | Chhattisgarh            | 58            | 36        | 0         |
# | 2020-05-05   | 67852            | NULL        | 5104        | Delhi                   | 4898          | 1431      | 64        |
# | 2020-05-05   | 3096             | NULL        | 7           | Goa                     | 7             | 7         | 0         |
# | 2020-05-05   | 89632            | 83387       | 6245        | Gujarat                 | 5804          | 1195      | 319       |
# | 2020-05-05   | 40982            | 36806       | 548         | Haryana                 | 517           | 254       | 6         |
# | 2020-05-05   | 7893             | 7800        | 42          | Himachal Pradesh        | 41            | 38        | 1         |
# | 2020-05-05   | 31312            | 30571       | 741         | Jammu and Kashmir       | 726           | 303       | 8         |
# | 2020-05-05   | 15064            | 14939       | 125         | Jharkhand               | 115           | 27        | 3         |
# | 2020-05-05   | 83806            | 78860       | 673         | Karnataka               | 659           | 324       | 28        |
# | 2020-05-05   | 36312            | 35244       | 502         | Kerala                  | 500           | 462       | 4         |
# | 2020-05-05   | 54595            | 48931       | 3049        | Madhya Pradesh          | 3049          | 1000      | 176       |
# | 2020-05-05   | 175323           | 162349      | 14541       | Maharashtra             | 14541         | 2465      | 583       |
# | 2020-05-05   | 1944             | 1822        | 12          | Meghalaya               | 12            | 10        | 1         |
# | 2020-05-05   | 188              | NULL        | 1           | Mizoram                 | 1             | 0         | 0         |
# | 2020-05-05   | 44663            | NULL        | 170         | Odisha                  | 170           | 60        | 1         |
# | 2020-05-05   | 3560             | 3444        | 12          | Puducherry              | 9             | 6         | 0         |
# | 2020-05-05   | 30199            | 23352       | 1451        | Punjab                  | 1233          | 128       | 23        |
# | 2020-05-05   | 134987           | 128297      | 3158        | Rajasthan               | 3061          | 1394      | 77        |
# | 2020-05-05   | 174828           | 170174      | 4058        | Tamil Nadu              | 3550          | 1409      | 31        |
# | 2020-05-05   | 5850             | 5820        | 30          | Tripura                 | 29            | 2         | 0         |
# | 2020-05-05   | 105234           | 101389      | 2880        | Uttar Pradesh           | 2859          | 944       | 53        |
# | 2020-05-05   | 8060             | 7357        | 61          | Uttarakhand             | 60            | 39        | 1         |
# | 2020-05-05   | 27571            | NULL        | 1344        | West Bengal             | 1259          | 218       | 133       |
# | 2020-05-06   | 141274           | 139497      | 1777        | Andhra Pradesh          | 4223          | 2539      | 71        |
# | 2020-05-06   | 1039             | 857         | 2           | Arunachal Pradesh       | 42            | 1         | 0         |
# | 2020-05-06   | 29328            | NULL        | 539         | Bihar                   | 4493          | 2210      | 29        |
# | 2020-05-06   | 1785             | 1641        | 120         | Chandigarh              | 301           | 214       | 5         |
# | 2020-05-06   | 22188            | 20873       | 59          | Chhattisgarh            | 756           | 213       | 2         |
# | 2020-05-06   | 4967             | 4966        | 1           | Dadra and Nagar Haveli  | 12            | 1         | 0         |
# | 2020-05-06   | 71934            | NULL        | 5532        | Delhi                   | 25004         | 9898      | 650       |
# | 2020-05-06   | 3411             | NULL        | 7           | Goa                     | 166           | 57        | 0         |
# | 2020-05-06   | 95191            | 88566       | 6625        | Gujarat                 | 18584         | 12667     | 1155      |
# | 2020-05-06   | 43279            | 38590       | 594         | Haryana                 | 3281          | 2134      | 24        |
# | 2020-05-06   | 8491             | 8055        | 43          | Himachal Pradesh        | 383           | 179       | 5         |
# | 2020-05-06   | 34277            | 33502       | 775         | Jammu and Kashmir       | 3142          | 1048      | 35        |
# | 2020-05-06   | 15908            | 15799       | 127         | Jharkhand               | 793           | 354       | 6         |
# | 2020-05-06   | 88777            | 83056       | 693         | Karnataka               | 4320          | 1610      | 57        |
# | 2020-05-06   | 37546            | 36210       | 502         | Kerala                  | 1588          | 690       | 14        |
# | 2020-05-06   | 54595            | 51479       | 3138        | Madhya Pradesh          | 8762          | 5637      | 377       |
# | 2020-05-06   | 181746           | 167205      | 15525       | Maharashtra             | 77793         | 33681     | 2710      |
# | 2020-05-06   | 195              | NULL        | 1           | Mizoram                 | 17            | 1         | 0         |
# | 2020-05-06   | 763              | 712         | 0           | Nagaland                | 80            | 0         | 0         |
# | 2020-05-06   | 47454            | NULL        | 185         | Odisha                  | 2478          | 1416      | 7         |
# | 2020-05-06   | 3641             | 3554        | 12          | Puducherry              | 82            | 25        | 0         |
# | 2020-05-06   | 32060            | 24303       | 1526        | Punjab                  | 2415          | 2043      | 47        |
# | 2020-05-06   | 139580           | 134172      | 3317        | Rajasthan               | 9862          | 7104      | 213       |
# | 2020-05-06   | 189              | 189         | 0           | Sikkim                  | 2             | 0         | 0         |
# | 2020-05-06   | 188241           | 182541      | 4829        | Tamil Nadu              | 27256         | 14902     | 220       |
# | 2020-05-06   | 6228             | 6185        | 43          | Tripura                 | 644           | 173       | 0         |
# | 2020-05-06   | 109888           | 106043      | 2998        | Uttar Pradesh           | 9237          | 5439      | 245       |
# | 2020-05-06   | 8346             | 7698        | 61          | Uttarakhand             | 1153          | 297       | 10        |
# | 2020-05-06   | 30141            | NULL        | 1456        | West Bengal             | 6876          | 2768      | 355       |
# | 2020-06-04   | 413733           | 409621      | 3377        | Andhra Pradesh          | 226           | 1         | 3         |
# +--------------+------------------+-------------+-------------+-------------------------+---------------+-----------+-----------+
# 100 rows selected (26.13 seconds)
#
# 0: jdbc:hive2://m02.itversity.com:10000/> create table covid_details as
# . . . . . . . . . . . . . . . . . . . . > select /* +MAPJOIN(t) */ t.date_time, t.total_samples, t.negative, t.positive, t.state, ci.confirmed, ci.cured, ci.death
# . . . . . . . . . . . . . . . . . . . . > from state_testing_itv002768_orc t join covid_india_itv002768_orc ci
# . . . . . . . . . . . . . . . . . . . . > on t.date_time=ci.date_time and t.state=ci.state;
# ```
